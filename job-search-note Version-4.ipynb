// %%
type Course = {
  course_title: string;
  catalog_number: string;
  credit_hours: number;
  minimum_grade?: string;
  designation?: string;
  status: string;
};

type Term = {
  term_id: number;
  credit_range: string;
  courses: Course[];
  total_hours: number;
  notes: string[];
};

type CourseList = Term[];

const courseList: CourseList = [
  {
    term_id: 1,
    credit_range: "0 - 15",
    courses: [
      {
        course_title: "Principles of Programming",
        subject: "CSE",
        catalog_number: "110",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "Completed",
        strm: 2247,
      },
      {
        course_title: "The ASU Experience",
        subject: "ASU",
        catalog_number: "101-CAI",
        credit_hours: 1,
        status: "Completed",
        strm: 2247,
      },
      {
        course_title: "First-Year Composition",
        subject: "ENG",
        catalog_number: "101 ",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "Completed",
        strm: 2247,
      },
      {
        course_title: "Introduction to Engineering",
        subject: "FSE",
        catalog_number: "100",
        credit_hours: 2,
        minimum_grade: "C",
        designation: "Critical",
        status: "Completed",
        strm: 2247,
      },
      {
        course_title: "Calculus for Engineers I",
        subject: "MAT",
        catalog_number: "265",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "Completed",
        strm: 2247,
      },
    ],
    total_hours: 15,
    notes: [
      "Complete Mathematics (MATH) requirement.",
      "First-Year Seminar required of all first-year students and should be taken in the first semester.",
    ],
  },
  {
    term_id: 2,
    credit_range: "15 - 30",
    courses: [
      {
        course_title: "Object-Oriented Programming and Data Structures",
        subject: "CSE",
        catalog_number: "205",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "Completed",
        strm: 2247,
      },
      {
        course_title: "First-Year Composition",
        subject: "ENG",
        catalog_number: "101 ",
        credit_hours: 3,
        minimum_grade: "C",
        status: "Completed",
        strm: 2247,
      },
      {
        course_title: "Calculus for Engineers II",
        subject: "MAT",
        catalog_number: "266",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "Completed",
        strm: 2247,
      },
    ],
    total_hours: 15,
    notes: [
      "Complete ENG 101 OR ENG 105 OR ENG 107 course(s).",
      "Complete MAT 170 OR MAT 171 OR MAT 265 OR MAT 270 course(s).",
      "Minimum 2.00 GPA ASU Cumulative.",
    ],
  },
  {
    term_id: 3,
    credit_range: "30 - 46",
    courses: [
      {
        course_title: "Digital Design Fundamentals",
        subject: "EEE",
        catalog_number: "120",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "In Progress",
        strm: 2247,
      },
      {
        course_title: "Introduction to Programming Languages",
        subject: "CSE",
        catalog_number: "240",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "In Progress",
        strm: 2247,
      },
      {
        course_title: "Discrete Mathematical Structures",
        subject: "MAT",
        catalog_number: "243",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "In Progress",
        strm: 2247,
      },
      {
        course_title: "Calculus for Engineers III or Logic in Computer Science",
        subject: "MAT",
        catalog_number: "267 ",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "Not Started",
        strm: 2247,
      },
    ],
    total_hours: 16,
    notes: [
      "Complete MAT 266 OR MAT 271 course(s).",
      "Prep for success using the Sophomore Guide.",
    ],
  },
  {
    term_id: 4,
    credit_range: "46 - 62",
    courses: [
      {
        course_title: "Computer Organization and Assembly Language Programming",
        subject: "CSE",
        catalog_number: "230",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "In Progress",
        strm: 2247,
      },
      {
        course_title: "Data Structures and Algorithms",
        subject: "CSE",
        catalog_number: "310",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "In Progress",
        strm: 2247,
      },
      {
        course_title:
          "Probability and Statistics for Engineering Problem Solving",
        subject: "IEE",
        catalog_number: "380",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Critical",
        status: "In Progress",
        strm: 2247,
      },
    ],
    total_hours: 16,
    notes: [
      "Complete CSE 259 OR MAT 267 OR MAT 272 course(s).",
      "Minimum 2.00 GPA ASU Cumulative.",
      "Pursue undergraduate research experiences.",
    ],
  },
  {
    term_id: 5,
    credit_range: "62 - 78",
    courses: [
      {
        course_title: "Introduction to Theoretical Computer Science",
        subject: "CSE",
        catalog_number: "355",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
      {
        course_title: "Computing Ethics",
        subject: "CSE",
        catalog_number: "301",
        credit_hours: 1,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
      {
        course_title: "Introduction to Software Engineering",
        subject: "CSE",
        catalog_number: "360",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
      {
        course_title: "Information Assurance",
        subject: "CSE",
        catalog_number: "365",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
      {
        course_title: "Applied Linear Algebra",
        subject: "MAT",
        catalog_number: "343",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
    ],
    total_hours: 16,
    notes: [
      "Plan for success using the Junior Guide.",
      "Network at student organization competitions or professional societies.",
    ],
  },
  {
    term_id: 6,
    credit_range: "78 - 93",
    courses: [
      {
        course_title: "Principles of Programming Languages",
        subject: "CSE",
        catalog_number: "340",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
      {
        course_title: "Operating Systems",
        subject: "CSE",
        catalog_number: "330",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
      {
        course_title:
          "Database Management or Computer Networks or Distributed Software Development",
        subject: "CSE",
        catalog_number: "412",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
    ],
    total_hours: 15,
    notes: [
      "Research and prepare for graduate school.",
      "Apply for an engineering accelerated program.",
      "Develop a professional profile online.",
    ],
  },
  {
    term_id: 7,
    credit_range: "93 - 108",
    courses: [
      {
        course_title: "Computer Science Capstone Project I",
        subject: "CSE",
        catalog_number: "485",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
    ],
    total_hours: 15,
    notes: [
      "Plan for success using the Senior Guide.",
      "Use Handshake to apply for full-time positions.",
      "Complete an in-person or virtual practice interview.",
    ],
  },
  {
    term_id: 8,
    credit_range: "108 - 120",
    courses: [
      {
        course_title: "Computer Science Capstone Project II",
        subject: "CSE",
        catalog_number: "486",
        credit_hours: 3,
        minimum_grade: "C",
        designation: "Necessary",
        status: "Not Started",
        strm: 2247,
      },
    ],
    total_hours: 12,
    notes: [
      "Ensure all graduation requirements are met.",
      "Review all completed coursework and prepare for graduation ceremonies.",
    ],
  },
];

const jobQuery: string = "Entry Level Software Developer in node.js";

// %%
import axiod from "https://deno.land/x/axiod/mod.ts";
import { config } from "https://deno.land/x/dotenv/mod.ts";

const env = config({ path: "./.env", export: true });

async function fetchData(): Promise<string> {
  try {
    const descriptions: string[] = [];

    await Promise.all(
      courseList.flatMap((term) =>
        term.courses
          .filter((course) => course.status === "Completed")
          .map((course) => fetchCourseDescription(course))
      )
    ).then((results) => {
      descriptions.push(...results);
    });

    return descriptions.join("|");
  } catch (error) {
    console.error("Error fetching data:", error);
    return "";
  }
}

async function fetchCourseDescription(course: Course): Promise<string> {
  const { strm, catalog_number, subject, course_title } = course;
  const url = `https://api.myasuplat-dpl.asu.edu/api/course/${strm}/subject/${subject}/${catalog_number}`;

  try {
    const response = await axiod.get(url);
    const [data] = response.data;

    if (!data || !data.fullDescription) {
      throw new Error("Invalid response structure");
    }

    return `${course_title} (${catalog_number}): ${data.fullDescription}`;
  } catch (error) {
    console.error(
      `Error fetching course description for ${catalog_number}:`,
      error
    );
    return `${course_title} (${catalog_number}): Description not available`;
  }
}

async function fetchJobListings(
  jobQuery: string
): Promise<{ job_title: string; employment_type: string }[]> {
  try {
    const response = await axiod.get("https://serpapi.com/search.json", {
      params: {
        engine: "google_jobs",
        q: jobQuery.toLowerCase(),
        hl: "en",
        api_key: env.SERP_API_KEY,
      },
    });
    console.log("job responses:", response.data.jobs_results);

    // Extract the relevant data from the response and format it for the searchJobs function
    return response.data?.jobs_results?.map((job) => ({
      job_title: job.title,
      company_name: job.company_name,
      location: job.location,
      relatedLink: job.related_links[0]?.link || 'No related links',
    })) || [];
  } catch (error) {
    console.error("Error fetching jobs from SERP API:", error);
    return error.message;
  }
}

const matchedJobs = await fetchJobListings(jobQuery);
console.log("Jobs:", JSON.stringify(matchedJobs, null, 2));

const courseDescriptions: string = await fetchData();
console.log("Course descriptions:", courseDescriptions);
// Out:
// Jobs: [
//   {
//     "job_title": "Entry Level AWS Java/Nodejs Developer",
//     "company_name": "HiringMirror",
//     "location": "  South Corning, New York   ",
//     "relatedLink": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=HiringMirror&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCK4I"
//   },
//   {
//     "job_title": "JavaScript Developer (100% remote)",
//     "company_name": "TEKsystems",
//     "location": " Anywhere ",
//     "relatedLink": "http://www.teksystems.com/"
//   },
//   {
//     "job_title": "Full Stack Software Engineer - Node.js, Golang",
//     "company_name": "Genoa Employment Solutions Inc",
//     "location": "  Beaverton, OR   ",
//     "relatedLink": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=Genoa+Employment+Solutions+Inc&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCMYJ"
//   },
//   {
//     "job_title": "Mean Stack Developer - Node.js",
//     "company_name": "Search Solutions, LLC",
//     "location": "  Los Angeles, CA   ",
//     "relatedLink": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=Search+Solutions,+LLC&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCJIK"
//   },
//   {
//     "job_title": "Web - Node.js, React Full Stack Developer (Remote and Retained)",
//     "company_name": "Addison Group",
//     "location": "  Columbus, OH   ",
//     "relatedLink": "https://www.theaddisongroup.com/"
//   },
//   {
//     "job_title": "Front-End JavaScript Software Engineer",
//     "company_name": "Keylent",
//     "location": "  Glendale, CA   ",
//     "relatedLink": "http://www.keylent.com/"
//   },
//   {
//     "job_title": "MERN Stack Developer",
//     "company_name": "SynergisticIT",
//     "location": "  Lansdowne, PA   ",
//     "relatedLink": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=SynergisticIT&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCO4L"
//   },
//   {
//     "job_title": "Mid Level Node/JavaScript Engineer",
//     "company_name": "Motion Recruitment",
//     "location": " Anywhere ",
//     "relatedLink": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=Motion+Recruitment&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCK8M"
//   },
//   {
//     "job_title": "Mid Level Full Stack Node.js Developer",
//     "company_name": "MSR Collective",
//     "location": "  Las Vegas, NV   ",
//     "relatedLink": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=MSR+Collective&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCIMN"
//   },
//   {
//     "job_title": "JR/Entry level SQL Developer II C# and JavaScript",
//     "company_name": "CyberTec",
//     "location": "  Georgia   ",
//     "relatedLink": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=CyberTec&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCMgN"
//   }
// ]
// Course descriptions: Principles of Programming (110): Concepts of problem solving using an object-oriented programming language, algorithm design, structured programming, fundamental algorithms and techniques.|The ASU Experience (101-CAI): Students will learn about ASU's mission as the New American University, the importance and benefits of an entrepreneurial approach to problem solving, solutions to sustainability challenges, and the importance of social embeddedness.  Additionally, through various course discussions and assignments, students will examine the concept of academic integrity and its potential impact on their future, gain awareness of the value of engaging in research activities, and learn about taking an interdisciplinary perspective.|First-Year Composition (101 ): Discovers, organizes and develops ideas in relation to the writer's purpose, subject and audience. Emphasizes modes of written discourse and effective use of rhetorical principles.|Introduction to Engineering (100): Introduces the engineering design process; working in engineering teams; the profession of engineering; engineering models, written and oral technical communication skills.|Calculus for Engineers I (265): Limits and continuity, differential calculus of functions of one variable, introduction to integration.|Object-Oriented Programming and Data Structures (205): Problem solving by programming with an object-oriented programming language. Introduces data structures. Overview of computer science topics.|First-Year Composition (101 ): Discovers, organizes and develops ideas in relation to the writer's purpose, subject and audience. Emphasizes modes of written discourse and effective use of rhetorical principles.|Calculus for Engineers II (266): Methods of integration, applications of calculus, elements of analytic geometry, improper integrals, Taylor series.

// %%
import { ChatOpenAI } from "npm:@langchain/openai";

const model = new ChatOpenAI({
  apiKey: env.OPENAI_API_KEY,
  modelName: "gpt-4-1106-preview",
});
console.log("Model initialized...");
const response =
  await model.invoke(`You are an expert in analyzing the course descriptions of the courses the user has opted for, and jobs that are available and returning the top 5 job suggestion mached based on similarity and their match.
>>>>>INPUT<<<<<
###
course descriptions ${courseDescriptions},
Jobs ${JSON.stringify(matchedJobs, null, 2)}
###

Follow the instructions to achieve the best results:
==== INSTRUCTIONS ====
1. For the given course descriptions which is separated by "|", analyze the jobs the user can apply for.
2. Extract jobs titles from the provided of json (jobs - array of objects).
3. Perform an intelligent matching operation to extract the best suitable jobs for the user based on course descriptions.
4. Return the results in a clear format with job title, company name, location and related_link in JSON . Include a concise 2-3 line explanation for each job, describing why it was selected. This explanation should relate the job suitability to the courses taken by the user.
####
Example:-"This job matches your profile because it requires skills developed in your courses, making it a suitable option for your career progression."
####
==== END ====

==== IMPORTANT ====
1. Don’t return any code
2. Limit the response to 50 words
3. Just provide the list of best suitable job titles and short note on why from the given jobs list based on the course descriptions provided.
4. Do not include any jobs from your end.
5. If no suitable job matches are found based on the courses described, first politely apologize and inform the user that no job matches were found and suggest that the user modifies their job query to align more closely with their course description  and give the formatted response with status and message and alternative query suggestion. 
==== END ====

`);
console.log("Response:", response.content);
// Out:
// Model initialized...
// Response: ```json
// [
//   {
//     "job_title": "Entry Level AWS Java/Nodejs Developer",
//     "company_name": "HiringMirror",
//     "location": "South Corning, New York",
//     "related_link": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=HiringMirror&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCK4I",
//     "note": "Your background in object-oriented programming and data structures from Principles of Programming and Object-Oriented Programming courses aligns with the skills required for this position."
//   },
//   {
//     "job_title": "JavaScript Developer (100% remote)",
//     "company_name": "TEKsystems",
//     "location": "Anywhere",
//     "related_link": "http://www.teksystems.com/",
//     "note": "The expertise gained in object-oriented programming courses makes you a good fit for this remote JavaScript Developer role."
//   },
//   {
//     "job_title": "Mean Stack Developer - Node.js",
//     "company_name": "Search Solutions, LLC",
//     "location": "Los Angeles, CA",
//     "related_link": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=Search+Solutions,+LLC&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCJIK",
//     "note": "Your experience with object-oriented programming and data structures suggests compatibility with the requirements for a Mean Stack Developer position."
//   },
//   {
//     "job_title": "Web - Node.js, React Full Stack Developer (Remote and Retained)",
//     "company_name": "Addison Group",
//     "location": "Columbus, OH",
//     "related_link": "https://www.theaddisongroup.com/",
//     "note": "Courses on problem-solving with object-oriented programming and data structures match the Full Stack Developer's role utilizing Node.js and React."
//   },
//   {
//     "job_title": "Mid Level Full Stack Node.js Developer",
//     "company_name": "MSR Collective",
//     "location": "Las Vegas, NV",
//     "related_link": "https://www.google.com/search?sca_esv=ba8230b150562d15&hl=en&q=MSR+Collective&sa=X&ved=0ahUKEwi82u-N9NOGAxVNFVkFHTBCGggQmJACCIMN",
//     "note": "The programming and data structures knowledge from your courses suggests a good fit for the Mid Level Full Stack Node.js Developer position."
//   }
// ]
// ```
